# %%
import os
from Framework.utils.utils import load_txt
import matplotlib.pyplot as plt
from Framework.postprocessors.postprocessor_functions import split_score_by_labels

# %%
path = '/home/bolci/Documents/Projekty/5G_OPEN_RAN/Anomaly_detection/5G_Open_RAN/Results/Try_Preprocessing=abs_only_by_one_sample_no-epochs=50_lr=0.001_bs=32_model=CNN_AE'
#path = '/home/bolci//Documents/Projekty/5G_OPEN_RAN/Anomaly_detection/Anomaly_detection_old/Results_norm/results_batch-size=32_learning-rate=0.001/'


train_final_batch_score = 'train_final_per_batch.txt'
full_train_score_path = os.path.join(path, train_final_batch_score)
val_0 = load_txt(full_train_score_path)

#train_final_batch_score = 'valid_false_scores.txt'
#full_train_score_path = os.path.join(path, train_final_batch_score)
#val_1 = load_txt(full_train_score_path)


#train_final_batch_score = 'valid_epochs_labels.txt'
#full_train_score_path = os.path.join(path, train_final_batch_score)
#valid_class_0 = load_txt(full_train_score_path)

valid_final_batch_score = 'valid_epochs_labels.txt'
full_train_score_path = os.path.join(path, valid_final_batch_score)
valid_class = load_txt(full_train_score_path)
valid_class_0, valid_class_1 = split_score_by_labels(valid_class)



plt.figure()
plt.hist(val_0, bins=15, density=True, alpha=0.5, label='Histogram of Anomaly Scores', color='orange')
plt.title('DCAE PDF Approach: Estimated PDF of Anomaly Scores')
plt.xlabel('Anomaly Score')
plt.ylabel('Density')
#plt.xlim([0.004, 0.010])
plt.legend()
plt.grid(True)



plt.figure()
plt.hist(valid_class_0[:, 1], bins=15, density=True, alpha=0.5, label='Histogram of Anomaly Scores, valid_class_0', color='orange')
plt.title('DCAE PDF Approach: Estimated PDF of Anomaly Scores')
plt.xlabel('Anomaly Score')
plt.ylabel('Density')
#plt.xlim([0.004, 0.010])
plt.legend()
plt.grid(True)

plt.figure()
plt.hist(valid_class_1[:, 1], bins=15, density=True, alpha=0.5, label='Histogram of Anomaly Scores,  valid_class_1', color='purple')
plt.title('DCAE PDF Approach: Estimated PDF of Anomaly Scores')
plt.xlabel('Anomaly Score')
plt.ylabel('Density')
#plt.xlim([0.004, 0.010])
plt.legend()
plt.grid(True)




plt.show()

# %%
valid_class_0
# Out:
# array([[1.        , 0.01734666],
#        [1.        , 0.01012565],
#        [1.        , 0.00881631],
#        [1.        , 0.0084423 ],
#        [1.        , 0.00856201],
#        [1.        , 0.00459312],
#        [1.        , 0.00419155],
#        [1.        , 0.00483934],
#        [1.        , 0.00354221],
#        [1.        , 0.00373297],
#        [1.        , 0.00444079],
#        [1.        , 0.00377905],
#        [1.        , 0.00257074],
#        [1.        , 0.00368535],
#        [1.        , 0.00285357],
#        [1.        , 0.00271097],
#        [1.        , 0.00335291],
#        [1.        , 0.00399353],
#        [1.        , 0.00453612],
#        [1.        , 0.00284257],
#        [1.        , 0.00410149]])
